# %%
import matplotlib.pyplot as plt

plt.plot([1,4,9,16], 'rs-',c = "blue", lw = 5, marker = "p", ms = 20, mfc = "green", mec = "green")
plt.plot([1,4,9,16],'ro')
plt.show()
# Out:
# /var/folders/yw/97hrdtxj2l51l66m4xkn4p3c0000gn/T/ipykernel_25176/429973141.py:3: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "rs-" (-> marker='s'). The keyword argument will take precedence.
#   plt.plot([1,4,9,16], 'rs-',c = "blue", lw = 5, marker = "p", ms = 20, mfc = "green", mec = "green")
# /var/folders/yw/97hrdtxj2l51l66m4xkn4p3c0000gn/T/ipykernel_25176/429973141.py:3: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "rs-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot([1,4,9,16], 'rs-',c = "blue", lw = 5, marker = "p", ms = 20, mfc = "green", mec = "green")

# %%
import numpy as np
import math as ma

x = np.linspace(-np.pi, np.pi, 256)
c = np.cos(x)
plt.plot(x,c)
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi], ['$-\pi$', '$-\pi/2$', 0, '$\pi/2$', '$\pi$'])
plt.yticks([-1, 0, 1])
plt.show()
